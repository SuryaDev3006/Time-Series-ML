# %% [markdown]
# # Phase 0 — Project Initialisation
#
# ==============================================
#
# What this file does:
#     - Validates that all dependencies are installed correctly
#     - Sets up the MLflow tracking URI (local or DagsHub)
#     - Creates the full directory structure
#     - Generates the synthetic M5 dataset
#
# Run this ONCE before starting Phase 1.
#
# SDLC note: Phase 0 produces NO models and NO plots.
# It only produces:
#     - configs/ (already in repo)
#
#     - data/raw/Y_df.parquet
#
#     - data/raw/meta.parquet
#
#     - A validated MLflow connection

# %%
# %%
import os
import sys
from pathlib import Path

# ── Project root ───────────────────────────────────────────────────────────────
# This file lives in notebooks/. Adjust ROOT if you run from elsewhere.
__file__ = os.path.abspath("00_setup.ipynb")
ROOT = Path(__file__).parent.parent
sys.path.insert(0, str(ROOT))

# ── Create all directories ─────────────────────────────────────────────────────
DIRS = [
    "data/raw", "data/processed", "data/features", "data/splits",
    "artifacts/plots", "artifacts/metrics", "artifacts/models",
    "configs/data", "configs/features", "configs/models",
    "configs/evaluation", "configs/monitoring",
    "notebooks", "scripts",
]
for d in DIRS:
    (ROOT / d).mkdir(parents=True, exist_ok=True)

# %%
# ── MLflow setup ───────────────────────────────────────────────────────────────
import mlflow

TRACKING_URI = str(ROOT / "mlruns")
mlflow.set_tracking_uri(TRACKING_URI)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Python\Projects\Walmart M5\.venv\Scripts\python.exe: No module named pip

# %%
EXPERIMENT_NAME = "ts-forecast-platform-phase1"
mlflow.set_experiment(EXPERIMENT_NAME)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\registry.py:81, in StoreRegistry.get_store_builder(self, store_uri)
#      80 try:
# ---> 81     store_builder = self._registry[scheme]
#      82 except KeyError:
#
# KeyError: 'c'
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedModelRegistryStoreURIException Traceback (most recent call last)
# Cell In[4], line 2
#       1 EXPERIMENT_NAME = "ts-forecast-platform-phase1"
# ----> 2 mlflow.set_experiment(EXPERIMENT_NAME)
#
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\fluent.py:201, in set_experiment(experiment_name, experiment_id, trace_location)
#     193 if (experiment_name is not None and experiment_id is not None) or (
#     194     experiment_name is None and experiment_id is None
#     195 ):
#     196     raise MlflowException(
#     197         message="Must specify exactly one of: `experiment_id` or `experiment_name`.",
#     198         error_code=INVALID_PARAMETER_VALUE,
#     199     )
# --> 201 client = TrackingServiceClient(_resolve_tracking_uri())
#     203 is_newly_created = False
#     205 with _experiment_lock:
#
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:99, in TrackingServiceClient.__init__(self, tracking_uri)
#      94 self.tracking_uri = tracking_uri
#      95 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      96 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      97 # property method to ensure that the client is serializable, even if the store is not
#      98 # self.store
# ---> 99 self.store
#
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:103, in TrackingServiceClient.store(self)
#     101 @property
#     102 def store(self):
# --> 103     return utils._get_store(self.tracking_uri)
#
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:270, in _get_store(store_uri, artifact_uri)
#     269 def _get_store(store_uri=None, artifact_uri=None):
# --> 270     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\registry.py:45, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      42 from mlflow.tracking._tracking_service import utils
#      44 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 45 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\_tracking_service\registry.py:55, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      49 """
#      50 Retrieve the store associated with a resolved (non-None) store URI and an artifact URI.
#      51 Caching is done on resolved URIs because the meaning of an unresolved (None) URI may change
#      52 depending on external configuration, such as environment variables
#      53 """
#      54 with _building_store_lock:
# ---> 55     builder = self.get_store_builder(resolved_store_uri)
#      56     return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File c:\Python\Projects\Walmart M5\.venv\Lib\site-packages\mlflow\tracking\registry.py:83, in StoreRegistry.get_store_builder(self, store_uri)
#      81     store_builder = self._registry[scheme]
#      82 except KeyError:
# ---> 83     raise UnsupportedModelRegistryStoreURIException(
#      84         unsupported_uri=store_uri, supported_uri_schemes=list(self._registry.keys())
#      85     )
#      86 return store_builder
#
# UnsupportedModelRegistryStoreURIException:  Model registry functionality is unavailable; got unsupported URI 'c:\Python\Projects\Walmart M5\mlruns' for model registry data storage. Supported URI schemes are: ['', 'file', 'databricks', 'databricks-uc', 'uc', 'http', 'https', 'postgresql', 'mysql', 'sqlite', 'mssql']. See https://www.mlflow.org/docs/latest/tracking.html#storage for how to run an MLflow server against one of the supported backend storage locations.
